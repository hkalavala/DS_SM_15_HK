# %% [markdown]
# ### Cost Benefit Questions
#
# 1. How would you rephrase the business problem if your model was optimizing toward _precision_? i.e., How might the model behave differently, and what effect would it have?
# 2. How would you rephrase the business problem if your model was optimizing toward _recall_?
# 3. What would the most ideal model look like in this case?

# %% [markdown]
# ### Visualizing models over variables

# %%
# %matplotlib inline

# %%
import pandas as pd
import sklearn.linear_model as lm
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('../dataset/flight_delays.csv')
df = df.loc[df.DEP_DEL15.notnull()].copy()

# %%
df.head()
# Out:
#    DAY_OF_MONTH  DAY_OF_WEEK     FL_DATE UNIQUE_CARRIER  AIRLINE_ID CARRIER  \
# 0             1            4  2015-01-01             AA       19805      AA
# 1             1            4  2015-01-01             AA       19805      AA
# 2             1            4  2015-01-01             AA       19805      AA
# 3             1            4  2015-01-01             AA       19805      AA
# 4             1            4  2015-01-01             AA       19805      AA
#
#    ORIGIN_AIRPORT_ID  ORIGIN_AIRPORT_SEQ_ID  ORIGIN_CITY_MARKET_ID  \
# 0              12478                1247802                  31703
# 1              12892                1289203                  32575
# 2              12478                1247802                  31703
# 3              12892                1289203                  32575
# 4              11298                1129803                  30194
#
#    DEST_AIRPORT_ID  DEST_AIRPORT_SEQ_ID  DEST_CITY_MARKET_ID  CRS_DEP_TIME  \
# 0            12892              1289203                32575           900
# 1            12478              1247802                31703           900
# 2            12892              1289203                32575          1230
# 3            12478              1247802                31703          1220
# 4            12173              1217302                32134          1305
#
#    DEP_TIME  DEP_DEL15  Unnamed: 15
# 0     855.0        0.0          NaN
# 1     856.0        0.0          NaN
# 2    1226.0        0.0          NaN
# 3    1214.0        0.0          NaN
# 4    1754.0        1.0          NaN

# %%
df.describe()
# Out:
#         DAY_OF_MONTH    DAY_OF_WEEK     AIRLINE_ID  ORIGIN_AIRPORT_ID  \
# count  458311.000000  458311.000000  458311.000000      458311.000000
# mean       15.803053       4.048024   19977.381106       12671.392175
# std         8.921022       1.929048     399.158330        1519.173651
# min         1.000000       1.000000   19393.000000       10135.000000
# 25%         8.000000       2.000000   19790.000000       11292.000000
# 50%        16.000000       4.000000   19977.000000       12889.000000
# 75%        23.000000       6.000000   20366.000000       13930.000000
# max        31.000000       7.000000   21171.000000       16218.000000
#
#        ORIGIN_AIRPORT_SEQ_ID  ORIGIN_CITY_MARKET_ID  DEST_AIRPORT_ID  \
# count           4.583110e+05          458311.000000    458311.000000
# mean            1.267142e+06           31714.487246     12671.782322
# std             1.519171e+05            1286.064137      1519.250986
# min             1.013503e+06           30070.000000     10135.000000
# 25%             1.129202e+06           30615.000000     11292.000000
# 50%             1.288903e+06           31453.000000     12889.000000
# 75%             1.393003e+06           32467.000000     13930.000000
# max             1.621801e+06           35991.000000     16218.000000
#
#        DEST_AIRPORT_SEQ_ID  DEST_CITY_MARKET_ID   CRS_DEP_TIME       DEP_TIME  \
# count         4.583110e+05        458311.000000  458311.000000  458311.000000
# mean          1.267181e+06         31715.865238    1323.662952    1333.028542
# std           1.519248e+05          1286.731887     467.693510     479.639617
# min           1.013503e+06         30070.000000       5.000000       1.000000
# 25%           1.129202e+06         30615.000000     925.000000     930.000000
# 50%           1.288903e+06         31453.000000    1320.000000    1328.000000
# 75%           1.393003e+06         32467.000000    1720.000000    1729.000000
# max           1.621801e+06         35991.000000    2359.000000    2400.000000
#
#            DEP_DEL15  Unnamed: 15
# count  458311.000000          0.0
# mean        0.198507          NaN
# std         0.398876          NaN
# min         0.000000          NaN
# 25%         0.000000          NaN
# 50%         0.000000          NaN
# 75%         0.000000          NaN
# max         1.000000          NaN

# %%
df = df[df.DEP_DEL15.notnull()]
df = df.join(pd.get_dummies(df['CARRIER'], prefix='carrier'))
df = df.join(pd.get_dummies(df['DAY_OF_WEEK'], prefix='dow'))
df = df.join(pd.get_dummies(df['AIRLINE_ID'], prefix='airline'))
df = df.join(pd.get_dummies(df['ORIGIN_AIRPORT_ID'], prefix='origarpt'))
model = lm.LogisticRegression()
features = [i for i in df.columns if 'dow_' in i]
features  += [i for i in df.columns if 'carrier_' in i]
features += [i for i in df.columns if 'airline_' in i]
features += [i for i in df.columns if 'origarpt_' in i]

# %%
df.shape
# Out:
# (458311, 51)

# %%
features += ['CRS_DEP_TIME']
print features
model.fit(df[features[1:]], df['DEP_DEL15'])

df['probability'] = model.predict_proba(df[features[1:]]).T[1]
# Out:
# ['dow_1', 'dow_2', 'dow_3', 'dow_4', 'dow_5', 'dow_6', 'dow_7', 'carrier_AA', 'carrier_AS', 'carrier_B6', 'carrier_DL', 'carrier_EV', 'carrier_F9', 'carrier_HA', 'carrier_MQ', 'carrier_NK', 'carrier_OO', 'carrier_UA', 'carrier_US', 'carrier_VX', 'carrier_WN', 'airline_19393', 'airline_19690', 'airline_19790', 'airline_19805', 'airline_19930', 'airline_19977', 'airline_20304', 'airline_20355', 'airline_20366', 'airline_20398', 'airline_20409', 'airline_20416', 'airline_20436', 'airline_21171', 'origarpt_10135', 'origarpt_10136', 'origarpt_10140', 'origarpt_10141', 'origarpt_10146', 'origarpt_10155', 'origarpt_10157', 'origarpt_10158', 'origarpt_10165', 'origarpt_10170', 'origarpt_10185', 'origarpt_10208', 'origarpt_10257', 'origarpt_10268', 'origarpt_10279', 'origarpt_10299', 'origarpt_10333', 'origarpt_10372', 'origarpt_10397', 'origarpt_10408', 'origarpt_10423', 'origarpt_10431', 'origarpt_10434', 'origarpt_10469', 'origarpt_10529', 'origarpt_10551', 'origarpt_10561', 'origarpt_10599', 'origarpt_10620', 'origarpt_10627', 'origarpt_10631', 'origarpt_10666', 'origarpt_10685', 'origarpt_10693', 'origarpt_10713', 'origarpt_10721', 'origarpt_10728', 'origarpt_10731', 'origarpt_10732', 'origarpt_10739', 'origarpt_10747', 'origarpt_10754', 'origarpt_10779', 'origarpt_10781', 'origarpt_10785', 'origarpt_10792', 'origarpt_10800', 'origarpt_10821', 'origarpt_10849', 'origarpt_10868', 'origarpt_10874', 'origarpt_10918', 'origarpt_10926', 'origarpt_10930', 'origarpt_10980', 'origarpt_10990', 'origarpt_10994', 'origarpt_11003', 'origarpt_11013', 'origarpt_11041', 'origarpt_11042', 'origarpt_11049', 'origarpt_11057', 'origarpt_11066', 'origarpt_11067', 'origarpt_11076', 'origarpt_11092', 'origarpt_11097', 'origarpt_11109', 'origarpt_11111', 'origarpt_11122', 'origarpt_11140', 'origarpt_11146', 'origarpt_11150', 'origarpt_11193', 'origarpt_11203', 'origarpt_11252', 'origarpt_11259', 'origarpt_11267', 'origarpt_11274', 'origarpt_11278', 'origarpt_11292', 'origarpt_11298', 'origarpt_11308', 'origarpt_11315', 'origarpt_11337', 'origarpt_11413', 'origarpt_11423', 'origarpt_11433', 'origarpt_11447', 'origarpt_11471', 'origarpt_11481', 'origarpt_11503', 'origarpt_11525', 'origarpt_11537', 'origarpt_11540', 'origarpt_11577', 'origarpt_11587', 'origarpt_11603', 'origarpt_11612', 'origarpt_11617', 'origarpt_11618', 'origarpt_11624', 'origarpt_11630', 'origarpt_11637', 'origarpt_11638', 'origarpt_11641', 'origarpt_11648', 'origarpt_11695', 'origarpt_11697', 'origarpt_11721', 'origarpt_11775', 'origarpt_11778', 'origarpt_11823', 'origarpt_11865', 'origarpt_11867', 'origarpt_11884', 'origarpt_11898', 'origarpt_11905', 'origarpt_11921', 'origarpt_11953', 'origarpt_11973', 'origarpt_11977', 'origarpt_11980', 'origarpt_11982', 'origarpt_11986', 'origarpt_11995', 'origarpt_11996', 'origarpt_12003', 'origarpt_12007', 'origarpt_12012', 'origarpt_12016', 'origarpt_12094', 'origarpt_12129', 'origarpt_12156', 'origarpt_12173', 'origarpt_12177', 'origarpt_12191', 'origarpt_12197', 'origarpt_12206', 'origarpt_12217', 'origarpt_12255', 'origarpt_12264', 'origarpt_12265', 'origarpt_12266', 'origarpt_12278', 'origarpt_12280', 'origarpt_12320', 'origarpt_12323', 'origarpt_12335', 'origarpt_12339', 'origarpt_12343', 'origarpt_12389', 'origarpt_12391', 'origarpt_12402', 'origarpt_12441', 'origarpt_12448', 'origarpt_12451', 'origarpt_12478', 'origarpt_12511', 'origarpt_12519', 'origarpt_12523', 'origarpt_12758', 'origarpt_12819', 'origarpt_12884', 'origarpt_12888', 'origarpt_12889', 'origarpt_12891', 'origarpt_12892', 'origarpt_12896', 'origarpt_12898', 'origarpt_12915', 'origarpt_12945', 'origarpt_12951', 'origarpt_12953', 'origarpt_12954', 'origarpt_12982', 'origarpt_12992', 'origarpt_13029', 'origarpt_13061', 'origarpt_13076', 'origarpt_13127', 'origarpt_13158', 'origarpt_13184', 'origarpt_13198', 'origarpt_13204', 'origarpt_13230', 'origarpt_13232', 'origarpt_13241', 'origarpt_13244', 'origarpt_13256', 'origarpt_13264', 'origarpt_13277', 'origarpt_13290', 'origarpt_ ...

# %%
ax = plt.subplot(111)
colors = ['blue', 'green', 'red', 'purple', 'orange', 'brown']
for e, c in enumerate(colors):
    df[df[features[e]] == 1].plot(x='CRS_DEP_TIME', y='probability', kind='scatter', color = c, ax=ax)

ax.set(title='Probability of Delay\n Based on Day of Week and Time of Day')

# %% [markdown]
# ### Other Answers: visualizing Airline or the inverse

# %%
features = [i for i in df.columns if 'carrier_' in i]
features += ['CRS_DEP_TIME']
print features
model.fit(df[features[1:]], df['DEP_DEL15'])

df['probability_1'] = model.predict_proba(df[features[1:]]).T[1]
#...
# Out:
# ['carrier_AA', 'carrier_AS', 'carrier_B6', 'carrier_DL', 'carrier_EV', 'carrier_F9', 'carrier_HA', 'carrier_MQ', 'carrier_NK', 'carrier_OO', 'carrier_UA', 'carrier_US', 'carrier_VX', 'carrier_WN', 'CRS_DEP_TIME']

# %%
import matplotlib.pyplot as plt
from matplotlib import colors as mcolors
ax = plt.subplot(111)
#colors = ['blue', 'green', 'red', 'purple', 'orange', 'brown','black', 'pink']
colors = []
colors = dict(mcolors.BASE_COLORS, **mcolors.CSS4_COLORS)

for e, c in enumerate(colors):
    df[df[features[e]] == 1].plot(x='CRS_DEP_TIME', y='probability', kind='scatter', color = c, ax=ax , label=features[e])
    ax.legend()

ax.set(title='Probability of Delay\n Based on carrier')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-4ef798f208ed> in <module>()
#       7
#       8 for e, c in enumerate(colors):
# ----> 9     df[df[features[e]] == 1].plot(x='CRS_DEP_TIME', y='probability', kind='scatter', color = c, ax=ax , label=features[e])
#      10     ax.legend()
#      11
#
# /anaconda/envs/py27_ds_dt_13/lib/python2.7/site-packages/pandas/tools/plotting.pyc in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    3772                           fontsize=fontsize, colormap=colormap, table=table,
#    3773                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 3774                           sort_columns=sort_columns, **kwds)
#    3775     __call__.__doc__ = plot_frame.__doc__
#    3776
#
# /anaconda/envs/py27_ds_dt_13/lib/python2.7/site-packages/pandas/tools/plotting.pyc in plot_frame(data, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2641                  yerr=yerr, xerr=xerr,
#    2642                  secondary_y=secondary_y, sort_columns=sort_columns,
# -> 2643                  **kwds)
#    2644
#    2645
#
# /anaconda/envs/py27_ds_dt_13/lib/python2.7/site-packages/pandas/tools/plotting.pyc in _plot(data, x, y, subplots, ax, kind, **kwds)
#    2468         plot_obj = klass(data, subplots=subplots, ax=ax, kind=kind, **kwds)
#    2469
# -> 2470     plot_obj.generate()
#    2471     plot_obj.draw()
#    2472     return plot_obj.result
#
# /anaconda/envs/py27_ds_dt_13/lib/python2.7/site-packages/pandas/tools/plotting.pyc in generate(self)
#    1039     def generate(self):
#    1040         self._args_adjust()
# -> 1041         self._compute_plot_data()
#    1042         self._setup_subplots()
#    1043         self._make_plot()
#
# /anaconda/envs/py27_ds_dt_13/lib/python2.7/site-packages/pandas/tools/plotting.pyc in _compute_plot_data(self)
#    1148         if is_empty:
#    1149             raise TypeError('Empty {0!r}: no numeric data to '
# -> 1150                             'plot'.format(numeric_data.__class__.__name__))
#    1151
#    1152         self.data = numeric_data
#
# TypeError: Empty 'DataFrame': no numeric data to plot

# %% [markdown]
# ### Visualizing Performance Against Baseline

# %% [markdown]
# #### Visualizing AUC and comparing Models

# %%
from sklearn import dummy, metrics

# %%
model0 = dummy.DummyClassifier()
print features
model0.fit(df[features[1:]], df['DEP_DEL15'])
df['probability_0'] = model0.predict_proba(df[features[1:]]).T[1]

model1 = lm.LogisticRegression()
model.fit(df[features[1:]], df['DEP_DEL15'])
df['probability_1'] = model.predict_proba(df[features[1:]]).T[1]
# Out:
# ['dow_1', 'dow_2', 'dow_3', 'dow_4', 'dow_5', 'dow_6', 'dow_7', 'carrier_AA', 'carrier_AS', 'carrier_B6', 'carrier_DL', 'carrier_EV', 'carrier_F9', 'carrier_HA', 'carrier_MQ', 'carrier_NK', 'carrier_OO', 'carrier_UA', 'carrier_US', 'carrier_VX', 'carrier_WN', 'airline_19393', 'airline_19690', 'airline_19790', 'airline_19805', 'airline_19930', 'airline_19977', 'airline_20304', 'airline_20355', 'airline_20366', 'airline_20398', 'airline_20409', 'airline_20416', 'airline_20436', 'airline_21171', 'origarpt_10135', 'origarpt_10136', 'origarpt_10140', 'origarpt_10141', 'origarpt_10146', 'origarpt_10155', 'origarpt_10157', 'origarpt_10158', 'origarpt_10165', 'origarpt_10170', 'origarpt_10185', 'origarpt_10208', 'origarpt_10257', 'origarpt_10268', 'origarpt_10279', 'origarpt_10299', 'origarpt_10333', 'origarpt_10372', 'origarpt_10397', 'origarpt_10408', 'origarpt_10423', 'origarpt_10431', 'origarpt_10434', 'origarpt_10469', 'origarpt_10529', 'origarpt_10551', 'origarpt_10561', 'origarpt_10599', 'origarpt_10620', 'origarpt_10627', 'origarpt_10631', 'origarpt_10666', 'origarpt_10685', 'origarpt_10693', 'origarpt_10713', 'origarpt_10721', 'origarpt_10728', 'origarpt_10731', 'origarpt_10732', 'origarpt_10739', 'origarpt_10747', 'origarpt_10754', 'origarpt_10779', 'origarpt_10781', 'origarpt_10785', 'origarpt_10792', 'origarpt_10800', 'origarpt_10821', 'origarpt_10849', 'origarpt_10868', 'origarpt_10874', 'origarpt_10918', 'origarpt_10926', 'origarpt_10930', 'origarpt_10980', 'origarpt_10990', 'origarpt_10994', 'origarpt_11003', 'origarpt_11013', 'origarpt_11041', 'origarpt_11042', 'origarpt_11049', 'origarpt_11057', 'origarpt_11066', 'origarpt_11067', 'origarpt_11076', 'origarpt_11092', 'origarpt_11097', 'origarpt_11109', 'origarpt_11111', 'origarpt_11122', 'origarpt_11140', 'origarpt_11146', 'origarpt_11150', 'origarpt_11193', 'origarpt_11203', 'origarpt_11252', 'origarpt_11259', 'origarpt_11267', 'origarpt_11274', 'origarpt_11278', 'origarpt_11292', 'origarpt_11298', 'origarpt_11308', 'origarpt_11315', 'origarpt_11337', 'origarpt_11413', 'origarpt_11423', 'origarpt_11433', 'origarpt_11447', 'origarpt_11471', 'origarpt_11481', 'origarpt_11503', 'origarpt_11525', 'origarpt_11537', 'origarpt_11540', 'origarpt_11577', 'origarpt_11587', 'origarpt_11603', 'origarpt_11612', 'origarpt_11617', 'origarpt_11618', 'origarpt_11624', 'origarpt_11630', 'origarpt_11637', 'origarpt_11638', 'origarpt_11641', 'origarpt_11648', 'origarpt_11695', 'origarpt_11697', 'origarpt_11721', 'origarpt_11775', 'origarpt_11778', 'origarpt_11823', 'origarpt_11865', 'origarpt_11867', 'origarpt_11884', 'origarpt_11898', 'origarpt_11905', 'origarpt_11921', 'origarpt_11953', 'origarpt_11973', 'origarpt_11977', 'origarpt_11980', 'origarpt_11982', 'origarpt_11986', 'origarpt_11995', 'origarpt_11996', 'origarpt_12003', 'origarpt_12007', 'origarpt_12012', 'origarpt_12016', 'origarpt_12094', 'origarpt_12129', 'origarpt_12156', 'origarpt_12173', 'origarpt_12177', 'origarpt_12191', 'origarpt_12197', 'origarpt_12206', 'origarpt_12217', 'origarpt_12255', 'origarpt_12264', 'origarpt_12265', 'origarpt_12266', 'origarpt_12278', 'origarpt_12280', 'origarpt_12320', 'origarpt_12323', 'origarpt_12335', 'origarpt_12339', 'origarpt_12343', 'origarpt_12389', 'origarpt_12391', 'origarpt_12402', 'origarpt_12441', 'origarpt_12448', 'origarpt_12451', 'origarpt_12478', 'origarpt_12511', 'origarpt_12519', 'origarpt_12523', 'origarpt_12758', 'origarpt_12819', 'origarpt_12884', 'origarpt_12888', 'origarpt_12889', 'origarpt_12891', 'origarpt_12892', 'origarpt_12896', 'origarpt_12898', 'origarpt_12915', 'origarpt_12945', 'origarpt_12951', 'origarpt_12953', 'origarpt_12954', 'origarpt_12982', 'origarpt_12992', 'origarpt_13029', 'origarpt_13061', 'origarpt_13076', 'origarpt_13127', 'origarpt_13158', 'origarpt_13184', 'origarpt_13198', 'origarpt_13204', 'origarpt_13230', 'origarpt_13232', 'origarpt_13241', 'origarpt_13244', 'origarpt_13256', 'origarpt_13264', 'origarpt_13277', 'origarpt_13290', 'origarpt_ ...

# %%
df.shape
# Out:
# (458311, 366)

# %%
ax = plt.subplot(111)
vals = metrics.roc_curve(df.DEP_DEL15, df.probability_0)
ax.plot(vals[0], vals[1])
vals = metrics.roc_curve(df.DEP_DEL15, df.probability_1)
ax.plot(vals[0], vals[1])

ax.set(title='Area Under the Curve for prediction delayed=1', ylabel='', xlabel='', xlim=(0, 1), ylim=(0, 1))
# Out:
# [(0, 1),
#  <matplotlib.text.Text at 0x11b26b0d0>,
#  (0, 1),
#  <matplotlib.text.Text at 0x11afc7ad0>,
#  <matplotlib.text.Text at 0x11eaf0b10>]

# %% [markdown]
# #### Visualizing Precision / Recall

# %%
ax = plt.subplot(111)
vals = metrics.precision_recall_curve(df.DEP_DEL15, df.probability_0)
ax.plot(vals[0], vals[1])
vals = metrics.precision_recall_curve(df.DEP_DEL15, df.probability_1)
ax.plot(vals[0], vals[1])

ax.set(title='Precision Recall Curve for prediction delayed=1', ylabel='', xlabel='', xlim=(0, 1), ylim=(0, 1))
# Out:
# [(0, 1),
#  <matplotlib.text.Text at 0x11ec48490>,
#  (0, 1),
#  <matplotlib.text.Text at 0x11ef99d50>,
#  <matplotlib.text.Text at 0x11f671350>]
